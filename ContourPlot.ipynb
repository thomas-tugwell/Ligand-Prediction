# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import cm
import matplotlib_inline

# %%
index = ['1','2','3','5','7','8','9','13','15','16','18','19','21','25','34','D','E','F','G','H']

# z = log_fluor_expr
z = [0.10720997,0.29666519,0.59439255,0.012837225,0.181843588,0.245512668,-0.004364805,0.056904851,-0.013228266,0.555094449,-0.180456064,0.204119983,0.264817823,0.491361694,0.008600172,0.747664862,0.71883301,0.209323305,0.364446073,0.07448883]
# x = cone angle
x = [202.4289064,161.1591651,117.9945617,145.193538,157.8881569,198.8856236,153.454599,158.9825776,159.8444741,243.1309972,158.6354572,157.8976104,190.0126478,179.9976285,158.6208107,226.30297,184.390302,207.6134749,212.5677198,159.3299818] 
# y = nbo_bds_e_min_boltz
y = [0.232030233,0.20561503,0.17124,0.217833874,0.198499748,0.169229601,0.23131,0.21163,0.234671213,0.1832527,0.23111,0.19365,0.17692,0.158602365,0.22426,0.24855,0.165214365,0.20328868,0.202589283,0.25102] 
 
# Creating figure
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
   
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.3,
        alpha = 0.2)
 
 
# Creating color map
my_cmap = plt.get_cmap('hsv')
 
# Creating plot
sctt = ax.scatter3D(x, y, z,
                    alpha = 0.8,
                    c = (x),
                    cmap = my_cmap,
                    marker ='^')
 
plt.title("simple 3D scatter plot")
ax.set_xlabel('Cone Angle', fontweight ='bold')
ax.set_ylabel('nbo_bds_e_min_boltz', fontweight ='bold')
ax.set_zlabel('log_fluor_expr', fontweight ='bold')
fig.colorbar(sctt, ax = ax, shrink = 0.5, aspect = 5)

for i in range(20):
    ax.text3D(x[i],y[i],z[i],index[i])
 
# show plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib  import cm
import numpy as np

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set_title("cone angle vs. nbo_bds_e_min_boltz",fontsize=14)
ax.set_xlabel("Cone Angle",fontsize=12)
ax.set_ylabel("nbo_bds_e_min_boltz",fontsize=12)
ax.grid(True,linestyle='-',color='0.75')

# scatter with colormap mapping to z value
ax.scatter(x,y,s=20,c=z, marker = 'o', cmap = 'Greens' )

#plt.colorbar(fig, ax=ax, orientation="horizontal", cmap="Greens")

for i in range(20):
    ax.annotate(index[i],(x[i],y[i] + 0.002))

plt.show()

# %%
# z = log_fluor_expr
z = [0.10720997,0.29666519,0.59439255,0.012837225,0.181843588,0.245512668,-0.004364805,0.056904851,-0.013228266,0.555094449,-0.180456064,0.204119983,0.264817823,0.491361694,0.008600172,0.747664862,0.71883301,0.209323305,0.364446073,0.07448883]
# x = cone angle
x = [202.4289064,161.1591651,117.9945617,145.193538,157.8881569,198.8856236,153.454599,158.9825776,159.8444741,243.1309972,158.6354572,157.8976104,190.0126478,179.9976285,158.6208107,226.30297,184.390302,207.6134749,212.5677198,159.3299818] 
# y = nbo_bds_e_min_boltz
y = [0.232030233,0.20561503,0.17124,0.217833874,0.198499748,0.169229601,0.23131,0.21163,0.234671213,0.1832527,0.23111,0.19365,0.17692,0.158602365,0.22426,0.24855,0.165214365,0.20328868,0.202589283,0.25102] 

# index for new ligands
index_new = ['I','J','K','L','M','N','O','P','Q','R','S','T']
# cone angle for new ligands
x_new = [151.96,157.84,158.65,159.167,165.52,168.32,170.33,174.16,199.76,199.81,199.90,219.50]
# cone angle for new ligands
y_new = [0.177,0.168,0.187,0.239,0.233,0.187,0.197,0.214,0.210,0.220,0.229,0.223]

plt.figure(figsize=(8,8))

plt.xlabel("Cone Angle")
plt.ylabel("Eσ*")
plt.scatter(x,y,c=z,cmap='jet') #current ligands
#plt.scatter(x_new, y_new, marker='^', c = "gray") # proposed ligands
plt.colorbar(label="log_fluor_expr", orientation="horizontal")
plt.grid(True,linestyle='-',color='0.75')
for i in range(20):
    plt.annotate(index[i],(x[i],y[i] + 0.003))
#for i in range(12):
   # plt.annotate(index_new[i],(x_new[i],y_new[i] + 0.003))
plt.show()
